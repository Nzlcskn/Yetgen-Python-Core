# %% [markdown]
# # Problem 1

# %%
pip install numpy
# Out:
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.9 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.9 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/60.9 kB 131.3 kB/s eta 0:00:01
#      ------------------- ------------------ 30.7/60.9 kB 146.3 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/60.9 kB 164.3 kB/s eta 0:00:01
#      -------------------------------------- 60.9/60.9 kB 202.6 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/16.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.3 MB 1.3 MB/s eta 0:00:13
#    ---------------------------------------- 0.1/16.3 MB 1.1 MB/s eta 0:00:15
#    ---------------------------------------- 0.2/16.3 MB 1.7 MB/s eta 0:00:10
#     --------------------------------------- 0.2/16.3 MB 1.4 MB/s eta 0:00:12
# ...

# %%
import numpy as np

matrix = np.random.randint(0, 11, size=5)
print("Orijinal matris:", matrix)
shape = matrix.shape
print("Matrisin boyutu:", shape)
reshaped_matrix = matrix.reshape(5, 1)
print("Yeniden boyutlandırıldı matris:\n", reshaped_matrix)


ndim = reshaped_matrix.ndim
print("Matrisin boyut sayısı:", ndim)
# Out:
# Orijinal matris: [ 3  8  7 10  9]
# Matrisin boyutu: (5,)
# Yeniden boyutlandırıldı matris:
#  [[ 3]
#  [ 8]
#  [ 7]
#  [10]
#  [ 9]]
# Matrisin boyut sayısı: 2

# %% [markdown]
# # Problem 2

# %%
import numpy as np

odnumbers = np.arange(1, 10, 2)  
print("Tek sayılardan oluşan matris:", odnumbers)


splitmatrix = np.array_split(odd_numbers, 2)
print("Parçalanmış matrisler:", splitmatrix)
combinedmatrix = np.concatenate(splitmatrix)
print("Birleştirilmiş matris:", combinedmatrix)
# Out:
# Tek sayılardan oluşan matris: [1 3 5 7 9]
# Parçalanmış matrisler: [array([1, 3, 5]), array([7, 9])]
# Birleştirilmiş matris: [1 3 5 7 9]

# %% [markdown]
# # Problem 3

# %%
import numpy as np


evennumbers = np.arange(6, 101, 2)  
randommatrix = np.random.choice(evennumbers, size=10, replace=False)
print("Rastgele matris:", randommatrix)

shape = randommatrix.shape
ndim = randommatrix.ndim
dtype = randommatrix.dtype
size = randommatrix.size

print("Matrisin boyutu:", shape)
print("Matrisin boyut sayısı (ndim):", ndim)
print("Matrisin veri tipi (dtype):", dtype)
print("Matrisin eleman sayısı (size):", size)
# Out:
# Rastgele matris: [32 26 46 86 50 38 70 88 40 56]
# Matrisin boyutu: (10,)
# Matrisin boyut sayısı (ndim): 1
# Matrisin veri tipi (dtype): int64
# Matrisin eleman sayısı (size): 10
